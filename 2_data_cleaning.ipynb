# %% [markdown]
# # Clean movie sequel data scraped from Box Office Mojo

# %%
import requests
import time
import random
import pickle
import pandas as pd
import numpy as np

# %%
with open('raw_movie_data.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
# check for duplicate entries - in data cleaning notebook next
# add a dummy variable for part of meta-franchise yes or no
# change '0s' in theateres to numpy NaN
# remove re-releases, IMAX, 3D - basically any movie with parentheses in it

# after removing dupes and re-releases/IMAX/etc., only then sort and get stats based on prior movie in the franchise

# %% [markdown]
# ## Check for re-releases, IMAX, 3D - movies with parentheses in the name

# %% [markdown]
# These movies are not truly new sequels, but rather re-releases or special releases of other sequels after the first release. I'm only interested in new sequels or remakes.

# %%
mask = (df.movie_title.str.contains("\([^\)]*\)"))
df[mask]
# Out:
#                       franchise_name  \
# 6                    Agatha Christie
# 10               Alice in Wonderland
# 34                        Amityville
# 44                            Arthur
# 53                            Avatar
# 71                        Barbershop
# 138                            Conan
# 151          The Dark Knight Trilogy
# 152          The Dark Knight Trilogy
# 153                    Dark Universe
# 182  Disney Live Action Reimaginings
# 183  Disney Live Action Reimaginings
# 184  Disney Live Action Reimaginings
# 185  Disney Live Action Reimaginings
# 188  Disney Live Action Reimaginings
# 189  Disney Live Action Reimaginings
# 199                            Earth
# 209                       Evangelion
# 210                       Evangelion
# 211                       Evangelion
# 212                        Evil Dead
# 218                     The Exorcist
# 226                   Fantastic Four
# 256                  Friday the 13th
# 260                  Friday the 13th
# 269                     Fright Night
# 275                     Ghostbusters
# 276                     Ghostbusters
# 277                     Ghostbusters
# 284                    The Godfather
# ..                               ...
# 381                    Indiana Jones
# 382                    Indiana Jones
# 447                             Jaws
# 470                        King Kong
# 491            The Lord of the Rings
# 600          Nightmare on Elm Street
# 617                         The Omen
# 641                 The Pink Panther
# 642                 The Pink Panther
# 655               Planet of the Apes
# 681                      Poltergeist
# 683                      Poltergeist
# 686                          Porky's
# 687                          Porky's
# 688                    Power Rangers
# 698                           Psycho
# 736                          Robocop
# 745                            Rocky
# 835                        Star Wars
# 837                        Star Wars
# 838                        Star Wars
# 839                        Star Wars
# 840                        Star Wars
# 842                        Star Wars
# 843                        Star Wars
# 844                        Star Wars
# 869     Teenage Mutant Ninja Turtles
# 885          Texas Chainsaw Massacre
# 896                        Toy Story
# 908                         The Trip
#
#                                            movie_title  rank   studio  \
# 6                  Murder on the Orient Express (2017)     1      Fox
# 10                          Alice in Wonderland (2010)     1       BV
# 34                        The Amityville Horror (2005)     2      MGM
# 44                                       Arthur (2011)     2       WB
# 53                 Avatar: Special Edition(Re-release)     2      Fox
# 71                             Beauty Shop((spin-off))     4      MGM
# 138                         Conan the Barbarian (2011)     3      LGF
# 151      The Dark Knight (2012 re-release)(Re-release)     4       WB
# 152        Batman Begins (2012 re-release)(Re-release)     5       WB
# 153                                   The Mummy (2017)     1     Uni.
# 182                        Beauty and the Beast (2017)     1       BV
# 183                         Alice in Wonderland (2010)     2       BV
# 184                             The Jungle Book (2016)     3       BV
# 185                              101 Dalmatians (1996)     4       BV
# 188                                  Cinderella (2015)     7       BV
# 189                               Pete's Dragon (2016)     8       BV
# 199                                       Earth (2009)     1       BV
# 209                 Evangelion: 3.0 You Can (Not) Redo     1    Elev.
# 210              Evangelion 2.0: You Can (Not) Advance     2    Elev.
# 211                 Evangelion 1.0 You Are (Not) Alone     3    Elev.
# 212                                   Evil Dead (2013)     1     TriS
# 218            The Exorcist Director's Cut(Re-release)     3       WB
# 226                              Fantastic Four (2005)     1      Fox
# 256                             Friday the 13th (1980)     1     Par.
# 260                             Friday the 13th (2009)     5  WB (NL)
# 269                                Fright Night (2011)     2       BV
# 275                                Ghostbusters (2016)     3     Sony
# 276                Ghostbusters (Re-issue)(Re-release)     4     Col.
# 277  Ghostbusters (30th Anniversary re-release)(Re-...     5     Sony
# 284               The Godfather (Re-issue)(Re-release)     4     Par.
# ..                                                 ...   ...      ...
# 381  Raiders of the Lost Ark (Re-issue) (1982)(Re-r...     5     Par.
# 382  Raiders of the Lost Ark (Re-issue) (1983)(Re-r...     6     Par.
# 447                 Jaws 2 (1980 re-issue)(Re-release)     5     Uni.
# 470                                   King Kong (1976)     2     Par.
# 491                       The Lord of the Rings (1978)     4       UA
# 600                   A Nightmare on Elm Street (2010)     6  WB (NL)
# 617                                    The Omen (2006)     3      Fox
# 641                            The Pink Panther (2006)     5     Sony
# 642                            The Pink Panther (1964)     6       UA
# 655                          Planet of the Apes (2001)     1      Fox
# 681                                 Poltergeist (2015)     3      Fox
# 683                 Poltergeist (re-issue)(Re-release)     5      MGM
# 686                         Porky's Revenge (Part III)     3      Fox
# 687                     Porky's (Re-issue)(Re-release)     4      Fox
# 688                               Power Rangers (2017)     1      LGF
# 698                                      Psycho (1998)     3     Uni.
# 736                                     RoboCop (2014)     3     Sony
# 745                   Rocky III (Re-issue)(Re-release)     8      MGM
# 835            Star Wars (Special Edition)(Re-release)    10      Fox
# 837  The Empire Strikes Back (Special Edition)(Re-r...    12      Fox
# 838   Return of the Jedi (Special Edition)(Re-release)    13      Fox
# 839  Star Wars: Episode I - The Phantom Menace (in ...    14      Fox
# 840                   Star Wars (Re-issue)(Re-release)    15      Fox
# 842     The Empire Strikes Back (Re-issue)(Re-release)    17      Fox
# 843          Return of the Jedi (Re-issue)(Re-release)    18      Fox
# 844  Attack of the Clones: The IMAX Experience (IMA...    19      Fox
# 869                Teenage Mutant Ninja Turtles (2014)     2     Par.
# 885  Texas Chainsaw Massacre: The Next Generation(R...     7    Lions
# 896                       Toy Story / Toy Story 2 (3D)     4       BV
# 908                                    The Trip (2011)     2      IFC
#
#      adjusted_domestic_gross release_date  theaters  \
# 6                  102608700   2017-11-10      3354
# 10                 385654200   2010-03-05      3739
# 34                  93219600   2005-04-15      3323
# 44                  37543900   2011-04-08      3276
# 53                  12750400   2010-08-27       812
# 71                  51946700   2005-03-30      2659
# 138                 24568300   2011-08-19      3015
# 151                  1781500   2012-07-19         0
# 152                  1776300   2012-07-19         0
# 153                 82129900   2017-06-09      4035
# 182                520271600   2017-03-17      4210
# 183                385654200   2010-03-05      3739
# 184                382070300   2016-04-15      4144
# 185                278902500   1996-11-27      2901
# 188                222649000   2015-03-13      3848
# 189                 81994000   2016-08-12      3702
# 199                 39306400   2009-04-22      1804
# 209                   201300   2014-01-10        82
# 210                   155700   2011-01-21        15
# 211                   130700   2009-07-03         6
# 212                 59288400   2013-04-05      3025
# 218                 67418600   2000-09-22      1708
# 226                221063400   2005-07-08      3619
# 256                135372500   1980-05-09         0
# 260                 79814800   2009-02-13      3105
# 269                 21118700   2011-08-19      3114
# 275                138124400   2016-07-15      3963
# 276                 24226600   1985-08-23       990
# 277                  4058900   2014-08-29       784
# 284                  2529500   1997-03-21        40
# ..                       ...          ...       ...
# 381                 66792800   1982-07-16      1330
# 382                 33076200   1983-03-25       628
# 447                 13718700   1980-02-15        26
# 470                226266800   1976-12-17         0
# 491                119281300   1978-11-15        31
# 600                 73327200   2010-04-30      3332
# 617                 76367000   2006-06-06      2723
# 641                114991500   2006-02-10      3477
# 642                107143500   2064-04-11         0
# 655                291312200   2001-07-27      3530
# 681                 51241900   2015-05-22      3242
# 683                  1559000   1983-05-20       593
# 686                 52944600   1985-03-22      1423
# 687                 16857900   1983-05-06      1192
# 688                 88011300   2017-03-24      3693
# 698                 41169300   1998-12-04      2489
# 736                 67369400   2014-02-12      3372
# 745                  2623600   1983-05-06      1071
# 835                275913300   1997-01-31      2375
# 837                134900900   1997-02-21      2322
# 838                 90742700   1997-03-14      2111
# 839                 50254200   2012-02-10      2655
# 840                 48218600   1982-08-13      1070
# 842                 41364100   1982-11-19      1006
# 843                 29033600   1985-03-29       894
# 844                 13338800   2002-11-01        58
# 869                216597400   2014-08-08      3980
# 885                   282600   1997-08-29        23
# 896                 36955900   2009-10-02      1752
# 908                  2332900   2011-06-10        62
#
#                                          movie_webpage
# 6    http://www.boxofficemojo.com/franchises/movies...
# 10   http://www.boxofficemojo.com/franchises/movies...
# 34   http://www.boxofficemojo.com/franchises/movies...
# 44   http://www.boxofficemojo.com/franchises/movies...
# 53   http://www.boxofficemojo.com/franchises/movies...
# 71   http://www.boxofficemojo.com/franchises/movies...
# 138  http://www.boxofficemojo.com/franchises/movies...
# 151  http://www.boxofficemojo.com/franchises/movies...
# 152  http://www.boxofficemojo.com/franchises/movies...
# 153  http://www.boxofficemojo.com/franchises/movies...
# 182  http://www.boxofficemojo.com/franchises/movies...
# 183  http://www.boxofficemojo.com/franchises/movies...
# 184  http://www.boxofficemojo.com/franchises/movies...
# 185  http://www.boxofficemojo.com/franchises/movies...
# 188  http://www.boxofficemojo.com/franchises/movies...
# 189  http://www.boxofficemojo.com/franchises/movies...
# 199  http://www.boxofficemojo.com/franchises/movies...
# 209  http://www.boxofficemojo.com/franchises/movies...
# 210  http://www.boxofficemojo.com/franchises/movies...
# 211  http://www.boxofficemojo.com/franchises/movies...
# 212  http://www.boxofficemojo.com/franchises/movies...
# 218  http://www.boxofficemojo.com/franchises/movies...
# 226  http://www.boxofficemojo.com/franchises/movies...
# 256  http://www.boxofficemojo.com/franchises/movies...
# 260  http://www.boxofficemojo.com/franchises/movies...
# 269  http://www.boxofficemojo.com/franchises/movies...
# 275  http://www.boxofficemojo.com/franchises/movies...
# 276  http://www.boxofficemojo.com/franchises/movies...
# 277  http://www.boxofficemojo.com/franchises/movies...
# 284  http://www.boxofficemojo.com/franchises/movies...
# ..                                                 ...
# 381  http://www.boxofficemojo.com/franchises/movies...
# 382  http://www.boxofficemojo.com/franchises/movies...
# 447  http://www.boxofficemojo.com/franchises/movies...
# 470  http://www.boxofficemojo.com/franchises/movies...
# 491  http://www.boxofficemojo.com/franchises/movies...
# 600  http://www.boxofficemojo.com/franchises/movies...
# 617  http://www.boxofficemojo.com/franchises/movies...
# 641  http://www.boxofficemojo.com/franchises/movies...
# 642  http://www.boxofficemojo.com/franchises/movies...
# 655  http://www.boxofficemojo.com/franchises/movies...
# 681  http://www.boxofficemojo.com/franchises/movies...
# 683  http://www.boxofficemojo.com/franchises/movies...
# 686  http://www.boxofficemojo.com/franchises/movies...
# 687  http://www.boxofficemojo.com/franchises/movies...
# 688  http://www.boxofficemojo.com/franchises/movies...
# 698  http://www.boxofficemojo.com/franchises/movies...
# 736  http://www.boxofficemojo.com/franchises/movies...
# 745  http://www.boxofficemojo.com/franchises/movies...
# 835  http://www.boxofficemojo.com/franchises/movies...
# 837  http://www.boxofficemojo.com/franchises/movies...
# 838  http://www.boxofficemojo.com/franchises/movies...
# 839  http://www.boxofficemojo.com/franchises/movies...
# 840  http://www.boxofficemojo.com/franchises/movies...
# 842  http://www.boxofficemojo.com/franchises/movies...
# 843  http://www.boxofficemojo.com/franchises/movies...
# 844  http://www.boxofficemojo.com/franchises/movies...
# 869  http://www.boxofficemojo.com/franchises/movies...
# 885  http://www.boxofficemojo.com/franchises/movies...
# 896  http://www.boxofficemojo.com/franchises/movies...
# 908  http://www.boxofficemojo.com/franchises/movies...
#
# [67 rows x 8 columns]

# %% [markdown]
# Some movies are remakes and have the new year of the remake in parentheses - for example, the Alice in Wonderland 2010 remake is called "Alice in Wonderland (2010)". One franchise actually has movies with a word in parentheses. These are data points we are interested in, so we'll have to remove the re-releases, IMAX and 3D movies separately so as to keep the remakes in the dataset.

# %%
mask = (df.movie_title.str.contains("\(Re-release\)"))
print(df[mask].movie_title)
df_no_rerelease = df[~mask]
len(df_no_rerelease)
# Out:
# 53                   Avatar: Special Edition(Re-release)
# 151        The Dark Knight (2012 re-release)(Re-release)
# 152          Batman Begins (2012 re-release)(Re-release)
# 218              The Exorcist Director's Cut(Re-release)
# 276                  Ghostbusters (Re-issue)(Re-release)
# 277    Ghostbusters (30th Anniversary re-release)(Re-...
# 284                 The Godfather (Re-issue)(Re-release)
# 340    Herbie Goes to Monte Carlo (Re-issue)(Re-release)
# 341           Herbie Goes Bananas (Re-issue)(Re-release)
# 381    Raiders of the Lost Ark (Re-issue) (1982)(Re-r...
# 382    Raiders of the Lost Ark (Re-issue) (1983)(Re-r...
# 447                   Jaws 2 (1980 re-issue)(Re-release)
# 683                   Poltergeist (re-issue)(Re-release)
# 687                       Porky's (Re-issue)(Re-release)
# 745                     Rocky III (Re-issue)(Re-release)
# 835              Star Wars (Special Edition)(Re-release)
# 837    The Empire Strikes Back (Special Edition)(Re-r...
# 838     Return of the Jedi (Special Edition)(Re-release)
# 839    Star Wars: Episode I - The Phantom Menace (in ...
# 840                     Star Wars (Re-issue)(Re-release)
# 842       The Empire Strikes Back (Re-issue)(Re-release)
# 843            Return of the Jedi (Re-issue)(Re-release)
# 844    Attack of the Clones: The IMAX Experience (IMA...
# 885    Texas Chainsaw Massacre: The Next Generation(R...
# Name: movie_title, dtype: object
# 950

# %% [markdown]
# Now search for IMAX releases.

# %%
mask = (df_no_rerelease.movie_title.str.contains("IMAX"))
print(df_no_rerelease[mask].movie_title)
df_no_rerelease_IMAX = df_no_rerelease[~mask]
len(df_no_rerelease_IMAX)
# Out:
# 326    Harry Potter IMAX Marathon
# 406    Harry Potter IMAX Marathon
# Name: movie_title, dtype: object
# 948

# %% [markdown]
# Now search for and check 3D releases to see if they are considered separately

# %%
mask = (df_no_rerelease_IMAX.movie_title.str.contains("3D"))
print(df_no_rerelease_IMAX[mask].movie_title)
# Out:
# 316    A Very Harold & Kumar 3D Christmas
# 760                                Saw 3D
# 810                Spy Kids 3D: Game Over
# 882                     Texas Chainsaw 3D
# 896          Toy Story / Toy Story 2 (3D)
# Name: movie_title, dtype: object

# %%
mask = df_no_rerelease_IMAX.movie_title.str.contains("Toy Story / Toy Story 2")
print(df_no_rerelease_IMAX[mask].movie_title)
df_no_rerelease_IMAX_3D = df_no_rerelease_IMAX[~mask]
len(df_no_rerelease_IMAX_3D)
# Out:
# 896    Toy Story / Toy Story 2 (3D)
# Name: movie_title, dtype: object
# 947

# %%
print(str(len(df) - len(df_no_rerelease_IMAX_3D)) + ' movies removed as re-releases, either as IMAX, 3D or standard re-releases.')
# Out:
# 27 movies removed as re-releases, either as IMAX, 3D or standard re-releases.

# %% [markdown]
# ## Find movies that are duplicated in the dataset under multiple franchises.

# %% [markdown]
# Sometimes a movie is classified under multiple franchises. This will skew the prediction, as we are basing modeling of current sequel box office on how the last movie did in the series. If Deadpool 2 belongs to both the X-Men franchise and the Deadpool franchise, then the exact Y value will be represented twice with two separate sets of X values (one set using Deadpool 1 as the comparator movie, while the other will use the most recent X-Men movie, which could be X-Men Evolution, or Logan).
#
# We will add a feature to classify if a movie originally appeared under multiple franchises (0 or 1), and then will remove the movie from the larger franchise in favor of the smaller, more specific franchise.

# %%
df_duplicates = df_no_rerelease_IMAX_3D.groupby(by=['movie_title', 'adjusted_domestic_gross'])['franchise_name'].agg('count').sort_values(ascending=False).reset_index()

# %%
df_duplicates.columns = ['movie_title', 'adjusted_domestic_gross', 'n_appearances']

# %%
mask = (df_duplicates.n_appearances > 1)
df_duplicates = df_duplicates[mask]
df_duplicates
# Out:
#                                           movie_title  \
# 0                  Batman v Superman: Dawn of Justice
# 1                              Spider-Man: Homecoming
# 2   The Lord of the Rings: The Fellowship of the Ring
# 3                                               Logan
# 4                                           Annabelle
# 5                                            Deadpool
# 6                                                Thor
# 7                                      Thor: Ragnarok
# 8                                Thor: The Dark World
# 9                      Dawn of the Planet of the Apes
# 10                            Solo: A Star Wars Story
# 11                                            Ant-Man
# 12                     Guardians of the Galaxy Vol. 2
# 13                            Guardians of the Galaxy
# 14                                      Batman Begins
# 15          The Hobbit: The Battle of the Five Armies
# 16                The Hobbit: The Desolation of Smaug
# 17                                Annabelle: Creation
# 18                               Ant-Man and the Wasp
# 19            Fantastic Beasts and Where To Find Them
# 20                            Avengers: Age of Ultron
# 21              Harry Potter and the Sorcerer's Stone
# 22           Harry Potter and the Prisoner of Azkaban
# 23          Harry Potter and the Order of the Phoenix
# 24             Harry Potter and the Half-Blood Prince
# 25                              The Dark Knight Rises
# 26                             Avengers: Infinity War
# 27                                    The Dark Knight
# 28                                         Deadpool 2
# 29                                 Kong: Skull Island
# 30                Harry Potter and the Goblet of Fire
# 31        Harry Potter and the Deathly Hallows Part 2
# 32        Harry Potter and the Deathly Hallows Part 1
# 33            Harry Potter and the Chamber of Secrets
# 34                                      The Wolverine
# 35                      Aliens Vs. Predator - Requiem
# 36                  The Hobbit: An Unexpected Journey
# 37                                         Maleficent
# 38                     Rise of the Planet of the Apes
# 39                                            Minions
# 40                         Captain America: Civil War
# 41                     War for the Planet of the Apes
# 42                                       Wonder Woman
# 43                                 Alien Vs. Predator
# 44                 Captain America: The First Avenger
# 45                Captain America: The Winter Soldier
# 46                           X-Men Origins: Wolverine
# 47                                           Iron Man
# 48                                         Iron Man 2
# 49                              The LEGO Batman Movie
# 50                                         Iron Man 3
# 51                                   Freddy Vs. Jason
# 52                              Marvel's The Avengers
# 53                         Alice in Wonderland (2010)
# 54              The Lord of the Rings: The Two Towers
# 55                                    Godzilla (2014)
# 56      The Lord of the Rings: The Return of the King
# 57                                       Man of Steel
# 58                       Rogue One: A Star Wars Story
# 59                    Alice Through the Looking Glass
#
#     adjusted_domestic_gross  n_appearances
# 0                 350467400              3
# 1                 342750600              3
# 2                 498942900              2
# 3                 234205600              2
# 4                  93005800              2
# 5                 387403700              2
# 6                 205797400              2
# 7                 314382100              2
# 8                 226626300              2
# 9                 236385100              2
# 10                211628000              2
# 11                199945600              2
# 12                398977800              2
# 13                377186500              2
# 14                293439800              2
# 15                284682800              2
# 16                288678200              2
# 17                104698600              2
# 18                112392200              2
# 19                243806300              2
# 20                490306500              2
# 21                512162900              2
# 22                368083100              2
# 23                388773700              2
# 24                370715500              2
# 25                527449300              2
# 26                675568400              2
# 27                680304200              2
# 28                315680600              2
# 29                173766800              2
# 30                413805500              2
# 31                439587500              2
# 32                338821000              2
# 33                411429500              2
# 34                154766500              2
# 35                 54259500              2
# 36                346556800              2
# 37                267052100              2
# 38                203965500              2
# 39                372942500              2
# 40                428277900              2
# 41                150647500              2
# 42                422418200              2
# 43                118419500              2
# 44                203826400              2
# 45                285749900              2
# 46                220875200              2
# 47                406208100              2
# 48                363361500              2
# 49                182063700              2
# 50                447459600              2
# 51                125509700              2
# 52                704231900              2
# 53                385654200              2
# 54                524861200              2
# 55                220827600              2
# 56                563689300              2
# 57                322894300              2
# 58                553645200              2
# 59                 80883900              2

# %% [markdown]
# #### Create a dataframe of the franchises that are in the above data frame so I know which ones need to be cleaned

# %% [markdown]
# * The 20 movies within the Marvel Universe tag can be removed, because they have their own series listed elsewhere in the dataset.
# * The Middle Earth franchise can also be removed.
# * Alien vs. Predator can be considered a new franchise with 2 movies.
# * Minions can be contained only in the Minions franchise, not Despicable Me
# * Star Wars Anthology can be removed
# * Batman v Superman movie was removed
# * DC Universe franchise can be removed completely - contained in other franchises
# * Wolverine and Deadpool movies can be removed from the X-Men franchise
# * The Dark Knight can be removed from Batman
#  Next: Godzilla, King Kong, Alice in Wonderland, Freddy vs Jason, Harry Potter, Malificent, Annabelle

# %% [markdown]
# ## Sort data by release date

# %%
df = df.sort_values(by=['franchise_name', 'release_date'])

# %%
df[['prior_movie_studio', 'prior_movie_release_date']] = df.groupby(['franchise_name'])['studio','release_date'].transform(lambda grp: grp.shift(1))

# %%
df['prior_movie_adj_domestic_gross'] = df.groupby(['franchise_name'])['adjusted_domestic_gross'].transform(lambda grp: grp.shift(1))

# %%
df.head()

# %%
df['time_since_prior_movie'] = df.release_date - df.prior_movie_release_date

# %%
# Ask the teachers if there's a better way to do this
franchise_start_date = df.groupby(by='franchise_name')['release_date'].min().reset_index()
franchise_start_date.columns = ['franchise_name', 'first_movie_release_date']
df = pd.merge(df,franchise_start_date,on='franchise_name')

# %%
df['time_since_first_movie'] = df.release_date - df.first_movie_release_date

# %%
# get first of each domestic gross for the first movie of each franchise, add that as a column, then divide current movie's gross by that
first_movie_adj_domestic_gross = pd.DataFrame(df.groupby(by=['franchise_name'])['adjusted_domestic_gross'].first())

# %%
first_movie_adj_domestic_gross.head()

# %%
first_movie_adj_domestic_gross.columns = ['first_movie_adj_domestic_gross']

# %%
first_movie_adj_domestic_gross.head()

# %%
df = pd.merge(df,first_movie_adj_domestic_gross,on='franchise_name')

# %%
df['percent_gross_change_vs_first_movie'] = df.adjusted_domestic_gross/df.first_movie_adj_domestic_gross

# %%
df['ln_adj_domestic_gross'] = np.log(df.adjusted_domestic_gross)

# %%
df['ln_prior_movie_adj_domestic_gross'] = np.log(df.prior_movie_adj_domestic_gross)

# %%
df['ln_first_movie_adj_domestic_gross'] = np.log(df.first_movie_adj_domestic_gross)

# %%
# see if a change in the studio from the last movie to this one impacts the outcome
test = df.head()
df.studio_changed_vs_prior_movie = np.where(df.studio == df.prior_movie_studio, 0, 1)
df.studio_changed_vs_prior_movie[df.order == 1] = np.NaN

# %%
df.head()

# %%
df.head()

# %%
sns.heatmap(df.corr(), cmap="Blues")

# %%
df.corr()

# %% [markdown]
# ### Remove all first movies in franchises - look only at 2nd and onward

# %%
mask = (df.order > 1)
sequel_df = df[mask]

# %%
sequel_df.tail()

# %%
sns.heatmap(sequel_df.corr(), cmap="Blues")

# %%
mask = (df.order > 2)
third_on_df = df[mask]

# %%
sns.heatmap(third_on_df.corr(), cmap="Blues")

# %% [markdown]
# ### Order of movie in the franchise
# 'rank' from BoxOfficeMojo is the rank by box office, not release order

# %%
df.head()

# %%
name = df.franchise_name[0]
counter = 1
rank_list = []
for i in df.franchise_name: 
    if i == name:
        rank_list.append(counter)
        counter+=1
    else:
        counter = 1
        rank_list.append(counter)
        counter+=1
        name = i
df['order'] = np.array(rank_list)

# %%
df.columns

# %% [markdown]
# ## Quick viz

# %%
import matplotlib.pyplot as plt

# %%
df['time_since_prior_movie_int'] = df.time_since_prior_movie.dt.days

# %%
df['time_since_first_movie_int'] = df.time_since_first_movie.dt.days

# %%
x = df.time_since_prior_movie_int
y = df.adjusted_domestic_gross

plt.scatter(x,y, alpha = 0.5);
plt.xlim(0,1500)

# %%
mask = (df.order > 1)
x = df.order[mask]
y = df.adjusted_domestic_gross[mask]

plt.scatter(x,y, alpha = 0.5);
plt.xlim(0,10)

# %%
mask = (df.order > 1)
x = df.order[mask]
y = df.percent_gross_change_vs_first_movie[mask]

plt.scatter(x,y, alpha = 0.5);
plt.xlim(0,10)
plt.ylim(0,2)

# %%
mask = (df.order > 1)
x = df.order#[mask]
y = df.ln_adj_domestic_gross#[mask]

plt.scatter(x,y, alpha = 0.5);
plt.xlim(0,10)
# plt.ylim(0,2)

# %%
mask = (df.time_since_first_movie_int > 0)
x = df.time_since_first_movie_int[mask]
y = df.adjusted_domestic_gross[mask]

plt.scatter(x,y, alpha = 0.5);
plt.xlim(0,10000)

# %%
df.groupby(by='time_since_prior_movie_int').size().sort_values(ascending=False).head()

# %%
x = df.time_since_prior_movie_int
y = df.percent_gross_change_vs_first_movie

plt.scatter(x,y, alpha = 0.5);
plt.ylim(0,2)
plt.xlim(0,1200)

# %%
x = df.time_since_first_movie_int
y = df.percent_gross_change_vs_first_movie

plt.scatter(x,y, alpha = 0.5);
plt.ylim(0,2)
plt.xlim(0,2000)

# %%
x = df.prior_movie_adj_domestic_gross
y = df.adjusted_domestic_gross

plt.scatter(x,y, alpha = 0.5);
#plt.ylim(0,2)
#plt.xlim(0,1000000)

# %%
x = df.ln_prior_movie_adj_domestic_gross
y = df.ln_adj_domestic_gross

plt.scatter(x,y, alpha = 0.5);
plt.ylim(14,21)
plt.xlim(14,21)
plt.xlabel('prior movie domestic gross\n(ln $, inflation adj)')
plt.ylabel('next movie domestic gross\n(ln $, inflation adj)')

# %%
df.groupby('')

# %%
df.head()

# %% [markdown]
# # First pass model

# %%
df.columns

# %%
y, X = patsy.dmatrices('ln_adj_domestic_gross ~ ln_prior_movie_adj_domestic_gross + ln_first_movie_adj_domestic_gross + time_since_prior_movie_int + time_since_first_movie_int + order + studio_changed_vs_prior_movie', data=sequel_df, return_type="dataframe")

model_a = sm.OLS(y, X)
fit_a = model_a.fit()
fit_a.summary()

# %%
fit_a.resid.plot(style='o', figsize=(12,8));

# %%
plt.hist(fit_a.resid)

# %%
df.shape

# %%
y, X = patsy.dmatrices('ln_adj_domestic_gross ~ ln_prior_movie_adj_domestic_gross + ln_first_movie_adj_domestic_gross + order + studio_changed_vs_prior_movie + time_since_prior_movie_int', data=sequel_df, return_type="dataframe")

model_b = sm.OLS(y, X)
fit_b = model_b.fit()
fit_b.summary()

# %%
fit_b.resid.plot(style='o', figsize=(12,8));

# %%
plt.hist(fit_b.resid)

# %%
import scipy

# %%
scipy.stats.normaltest(fit_b.resid)

# %%
np.random.seed(28041990)

# %% [markdown]
# # Code for The Numbers website for direct to video sequels

# %% [markdown]
# Below is getting data from The Numbers - include direct-to-video movies which is interesting, but they don't have sales data for all of those direct to video releases so it's tougher to assess. It might be useful down the line.

# %%
"""
url = 'https://www.the-numbers.com/movies/franchises'
response = requests.get(url)
response.status_code
# print(response.text)
page = response.text
soup = BeautifulSoup(page,"lxml")
# soup.find_all('table')
# soup.find('table').find_all('tr')[1:]

movie_count = 0
single = 0
franchises = 0
for link in soup.find('table').find_all('tr')[1:]:
    print(link.find('a')['href']) # put .text instead of ['href'] for the name of the franchise
    n = int(link.find_all('td')[1].text)
    print(link.find_all('td')[1].text) # print the next column - the number of movies
    movie_count += int(link.find_all('td')[1].text)
    if n == 1:
        single += 1
    franchises += 1
print(movie_count)
print(franchises)
print(single)
"""
